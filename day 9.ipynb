# %%
#characteristics 
#list is ordered collection
l=[1,2,3,'hi','hello']
print(l)
# Out:
# [1, 2, 3, 'hi', 'hello']

# %%
#indexing and slicing
l=(1,2,3,'hi','hello',2.56,100)
print(l[-2])
print(l[:4:-1])
print(l[-2:-4:1])
print(l[:100])
print(l[5:100:1])
print(l[5:3:1])
# Out:
# 2.56
# (100, 2.56)
# ()
# (1, 2, 3, 'hi', 'hello', 2.56, 100)
# (2.56, 100)
# ()

# %%
#empty list
l1=[]
l2=list()
print(type(l1),type(l2))
# Out:
# <class 'list'> <class 'list'>

# %%
#reading list of elements from user
l=input()
print(l)
# Out:
#  10 20 30
# 10 20 30

# %%
#reading list of elements from user
l=input().split()
print(l)
# Out:
#  10 20 30
# ['10', '20', '30']

# %%
#reading list of elements from user
l=map(int,input().split())
print(l)
# Out:
#  10 20 30
# ...

# %%
#reading list of elements from user
l=list(map(str,input().split(",")))
print(l)
# Out:
#  10,20,30
# ['10', '20', '30']

# %%
#reading list of elements from user
l=map(str,input().split(","))
print(l)
# Out:
#  10 20 30
# ...

# %% [markdown]
# # l=list(map(int,input().split()))
# element=int(input())
# if element in l:
#     print(element,"exists")
# else:
#     print(element,"does not exists")

# %%
# list methods
-items adding to list
 -append(item)-it adds element at the end of the list
 -extend(new list)- it adds all new lsit elements at end of the list
 -insert(pos,item)-it adds the item at specific postion

# %%
# delete items from list:
-remove(item)-it removes the specified item from the list if it exists,otherwise valueerror 
-pop(pos)-it removes and returns the value from the list for the specified position,otherwise'indexerror'. by defualt it will select last
